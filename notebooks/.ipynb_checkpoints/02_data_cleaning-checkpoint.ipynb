# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/student_stress.csv")

print(df.shape)
# Out:
# (39, 34)

# %%
#Remove unnecessary columns.

df = df.drop(columns=[
    "Timestamp",
    "Research Participation Consent\n"
])

print(df.shape)
# Out:
# (39, 32)

# %%
#Let's rename the columns to something professional.
new_columns = [
    "age",
    "gender",
    "university",
    "program",
    "year",
    "cgpa",
    "study_hours",
    "attendance",
    "assignment_stress",
    "exam_count",
    "sleep_hours",
    "social_media",
    "physical_activity",
    "part_time_job",
    "screen_time",
    "financial_stress",
    "social_support",
    "stress_q1",
    "stress_q2",
    "stress_q3",
    "stress_q4",
    "stress_q5",
    "stress_q6",
    "stress_q7",
    "stress_q8",
    "stress_q9",
    "stress_q10",
    "academic_life_satisfaction",
    "biggest_stress_reason",
    "thought_break",
    "career_stress",
    "academic_performance"
]

df.columns = new_columns

# %%
df.head()
# Out:
#         age  gender            university      program      year  \
# 0     20-22  Female  Tribhuvan University          BCA  4th Year
# 1  Above 25    Male                 Other  BSc Nursing  3rd Year
# 2     23-25    Male  Tribhuvan University    BE/B.Tech  4th Year
# 3     23-25    Male  Tribhuvan University          BCA  5th Year
# 4  Above 25    Male  Tribhuvan University     BSc CSIT  4th Year
#
#                 cgpa  study_hours attendance  assignment_stress   exam_count  \
# 0  Not Available Yet  Less than 1     60–70%                  2          1-2
# 1           3.0–3.49          3–4  Above 90%                  3          5-6
# 2            3.5–4.0          1–2  Above 90%                  4          1-2
# 3           3.0–3.49          1–2  Below 60%                  1  More than 6
# 4  Not Available Yet          1–2     71–80%                  2          1-2
#
#    ... stress_q6 stress_q7 stress_q8 stress_q9 stress_q10  \
# ...

# %%
df.to_csv("../data/processed/student_stress_clean.csv", index=False)
