# %%
import pandas as pd

df = pd.read_csv("../data/raw/student_stress.csv")

# %%
#See Dataset Shape
print("Rows and Columns:")
print(df.shape)
# Out:
# Rows and Columns:
# (39, 34)

# %%
#View First Rows
df.head()
# Out:
#            Timestamp Research Participation Consent\n How old are you?   \
# 0  7/5/2026 22:41:57     Yes, I agree to participate.             20-22
# 1  7/5/2026 23:01:57     Yes, I agree to participate.          Above 25
# 2   7/6/2026 4:30:56     Yes, I agree to participate.             23-25
# 3  7/6/2026 11:01:28     Yes, I agree to participate.             23-25
# 4  7/6/2026 21:36:53     Yes, I agree to participate.          Above 25
#
#   What is your gender?    Which university are you currently studying in?    \
# 0                Female                               Tribhuvan University
# 1                  Male                                              Other
# 2                  Male                               Tribhuvan University
# 3                  Male                               Tribhuvan University
# 4                  Male                               Tribhuvan University
#
#      What program are you currently enrolled in?    \
# ...

# %%
# Check Columns

print(df.columns.tolist())
# Out:
# ['Timestamp', 'Research Participation Consent\n', 'How old are you? ', 'What is your gender? ', '  Which university are you currently studying in?  ', '   What program are you currently enrolled in?  ', '  Which year are you currently studying in?  ', '  Current GPA/CGPA  ', 'On average, how many hours do you study per day (outside class)?', 'What is your approximate class attendance?', 'How often do you feel overwhelmed by assignments, projects, and deadlines? ', 'How many major exams, tests, or assessments have you completed during the current semester or year? ', 'How many hours of sleep do you get per night? ', 'On average, how much time do you spend on social media each day?', 'How often do you engage in physical activity or exercise?', '  Part-time Job  ', 'On average, what is your total daily screen time (including study and entertainment)?', 'How often do financial concerns related to your education cause you stress?', 'When you feel stressed, how often do you have someone yo
# ...

# %%
#  Check for Missing Values
df.isnull().sum()
# Out:
# Timestamp                                                                                                                         0
# Research Participation Consent\n                                                                                                  0
# How old are you?                                                                                                                  0
# What is your gender?                                                                                                              0
#   Which university are you currently studying in?                                                                                 0
#    What program are you currently enrolled in?                                                                                    0
#   Which year are you currently studying in?                                                                                       0
# ...

# %%
#dataset infoprmation
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 34 columns):
#  #   Column                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                          --------------  -----
#  0   Timestamp                                                                                                                       39 non-null     str
#  1   Research Participation Consent
#                                                                                                  39 non-null     str
#  2   How old are you?                                                                                                                39 non-null     str
# ...
